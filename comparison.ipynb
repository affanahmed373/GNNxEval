# %%
import matplotlib.pyplot as plt

# Sample data for multiple lines
x_values = [1, 2, 3, 4, 5]
y_values1 = [3, 5, 2, 6, 1]
y_values2 = [2, 4, 1, 5, 3]
y_values3 = [4, 3, 2, 1, 5]

# Create the line graph for each line
plt.plot(x_values, y_values1, label='Line 1')
plt.plot(x_values, y_values2, label='Line 2')
plt.plot(x_values, y_values3, label='Line 3')

# Set labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Lines Line Graph')

# Add a legend
plt.legend()

# Display the graph
plt.show()

# %%
1  0.0048006, 0.7821270 0.0093942 0.0829030
2  0.0055391, 0.8220088 0.0107438 0.0117922
3  0.0029541, 0.8415805 0.0058002 0.0428004
4  0.0014771, 0.8770310 0.0029191 0.0680301
5  0.0040620, 0.8268094 0.0079379 0.1001273
6  0.0051698, 0.8689069 0.0099474 0.0334298
7  0.0033234, 0.8205317 0.0065261 0.0451869
8  0.0025849, 0.8194239 0.0050969 0.0522613
9 0.0021039, 0.8569281 0.0041469 0.2135248
10 0.0030056, 0.8331830 0.0059049 0.1083208
11 0.0015028, 0.8232641 0.0029803 0.0950056
12 0.0015028, 0.8256687 0.0029800 0.1346806
13 0.0024045, 0.8334836 0.0047406 0.1916656
14  0.0021039, 0.8154493 0.0041605 0.1416324
15  0.0024045, 0.8412984 0.0047373 0.1419266
16 0.0024045, 0.9161406 0.0046750 0.2807985
17 0.0012679, 0.5880712 0.0025281 0.1387156
18  0.0007607, 0.5649946 0.0015189 0.2790257
19  0.0008114, 0.7092356 0.0016183 0.0764944
20  0.0009129, 0.6379773 0.0018212 0.0384463
21  0.0011665, 0.5644367 0.00232681 0.0327048
22 0.0009636, 0.6277831 0.0019222 0.0694633
23 0.0011665, 0.6263123 0.0023257 0.0358163
24 0.0011157, 0.5686970 0.0022258 0.2701116
# Out:
#   Cell In[6], line 1
#     1  0.0048006, 0.7821270 0.0093942 0.0829030
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.2
fig = plt.subplots(figsize =(12, 8))

x_data = ['Cora-GNN','Cora-GraphMask','Citeseer-GNN','Citeseer-GraphMask','Pubmed-GNN','Pubmed-GraphMask']
 
# set height of bar
GCN = [0.0829030, 0.1001273, 0.2135248, 0.1916656, 0.1387156,0.0327048]
GAT = [0.0117922, 0.0334298, 0.1083208, 0.1416324, 0.2790257, 0.0694633]
GIN = [0.0428004, 0.0451869, 0.0950056, 0.1419266,0.0764944,0.0358163]
GRAPHSAGE = [0.0680301, 0.0522613, 0.1346806, 0.2807985, 0.0384463, 0.2701116]

# Set position of bar on X axis
br1 = np.arange(len(GCN))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
 
# Make the plot
plt.bar(br1, GCN, color = 'teal',width = barWidth,
        edgecolor ='grey', label ='GCN')
plt.bar(br2, GAT,color = 'indigo' ,width = barWidth,
        edgecolor = 'grey', label ='GAT')
plt.bar(br3, GIN,color = 'maroon', width = barWidth,
        edgecolor ='grey', label ='GIN')
plt.bar(br4, GRAPHSAGE,color = 'salmon', width = barWidth,
        edgecolor ='grey', label ='GRAPHSAGE') 
# Adding Xticks
plt.xlabel('Dataset-Explainer', fontweight ='bold', fontsize = 15)
plt.ylabel('Unfaithfullness', fontweight ='bold', fontsize = 15)
plt.xticks(range(len(x_data)),x_data)
 
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.2
fig = plt.subplots(figsize =(12, 8))

x_data = ['Cora-GNN','Cora-GraphMask','Citeseer-GNN','Citeseer-GraphMask','Pubmed-GNN','Pubmed-GraphMask']
 
# set height of bar
GCN = [0.0093942, 0.0079379, 0.0041469, 0.0047406, 0.0025281,0.00232681]
GAT = [0.0107438, 0.0099474, 0.0059049 , 0.0041605, 0.0015189, 0.0019222]
GIN = [0.0058002, 0.0065261, 0.0029803, 0.0047373,0.0016183,0.0023257]
GRAPHSAGE = [0.0029191 , 0.0050969, 0.0029800, 0.0046750, 0.0018212, 0.0022258]

# Set position of bar on X axis
br1 = np.arange(len(GCN))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
 
# Make the plot
plt.bar(br1, GCN, color = 'teal',width = barWidth,
        edgecolor ='grey', label ='GCN')
plt.bar(br2, GAT,color = 'indigo' ,width = barWidth,
        edgecolor = 'grey', label ='GAT')
plt.bar(br3, GIN,color = 'maroon', width = barWidth,
        edgecolor ='grey', label ='GIN')
plt.bar(br4, GRAPHSAGE,color = 'salmon', width = barWidth,
        edgecolor ='grey', label ='GRAPHSAGE') 
# Adding Xticks
plt.xlabel('Dataset-Explainer', fontweight ='bold', fontsize = 15)
plt.ylabel('Characteristisation Score', fontweight ='bold', fontsize = 15)
plt.xticks(range(len(x_data)),x_data)
 
plt.legend()
plt.show()
